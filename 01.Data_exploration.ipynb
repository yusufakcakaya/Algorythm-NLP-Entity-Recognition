# %% [markdown]
# ## Import the dataset from nltk library.

# %%
from nltk.corpus import reuters

# %%
# Print the categories of reuters dataset
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
# ...

# %%
# Check for the documents in jobs category.
reuters.fileids(categories=['jobs'])
# Out:
# ['test/14867',
#  'test/14974',
#  'test/15045',
#  'test/15365',
#  'test/15485',
#  'test/16100',
#  'test/16158',
#  'test/17633',
#  'test/18533',
#  'test/18539',
#  'test/18616',
#  'test/18672',
#  'test/18987',
#  'test/18990',
#  'test/18993',
#  'test/18996',
#  'test/19000',
#  'test/19985',
#  'test/19986',
#  'test/20248',
#  'test/21525',
#  'training/10135',
#  'training/1040',
#  'training/11159',
#  'training/11160',
#  'training/11276',
#  'training/12507',
#  'training/12534',
#  'training/12555',
#  'training/12743',
#  'training/12752',
#  'training/12818',
#  'training/14771',
#  'training/2000',
#  'training/2197',
#  'training/2618',
#  'training/2746',
#  'training/3024',
#  'training/3472',
#  'training/3520',
#  'training/3717',
#  'training/4036',
#  'training/4091',
#  'training/4306',
#  'training/4698',
#  'training/4700',
#  'training/5215',
#  'training/5392',
#  'training/6158',
#  'training/6603',
#  'training/6951',
#  'training/7004',
# ...

# %%
x = reuters.paras(fileids=['training/9751'])
# printing original list 
print("The original list : " + str(x))
# Out:
# The original list : [[['KEATING', 'REVISES', 'DOWN', 'AUSTRALIAN', 'GROWTH', 'FORECAST', 'Treasurer', 'Paul', 'Keating', 'forecast', 'economic', 'growth', 'at', 'slightly', 'under', 'two', 'pct', 'in', 'the', 'financial', 'year', 'ending', 'June', 'this', 'year', ',', 'down', 'from', 'the', '2', '.', '25', 'pct', 'forecast', 'contained', 'in', 'the', '1986', '/', '87', 'budget', 'delivered', 'last', 'August', '.'], ['Australia', "'", 's', 'terms', 'of', 'trade', 'also', 'fell', ',', 'by', '18', 'pct', ',', 'over', 'the', 'past', 'two', 'years', ',', 'he', 'told', 'Parliament', '.'], ['Terms', 'of', 'trade', 'are', 'the', 'difference', 'between', 'import', 'and', 'export', 'price', 'indexes', '.'], ['Despite', 'the', 'figures', ',', 'the', 'budget', 'forecast', 'of', 'about', '1', '.', '75', 'pct', 'annual', 'growth', 'in', 'employment', 'would', 'be', 'met', ',', 'Keating', 'said', '.'], ['Unemployment', 'is', 'currently', 'at', '8', '.', '2', 'pct', 'of', 'the', 'workforce', '.'], [
# ...

# %% [markdown]
# ### Perform pre-processing on the document from reuters dataset.

# %%
def get_list_values(text, temp=[]):
    for item in text:
        if type(item) == list:
            temp = get_list_values(item, temp)

        else:
            temp.append(item)

    return temp

 
result = ' '.join(get_list_values(x))
result
# Out:
# 'KEATING REVISES DOWN AUSTRALIAN GROWTH FORECAST Treasurer Paul Keating forecast economic growth at slightly under two pct in the financial year ending June this year , down from the 2 . 25 pct forecast contained in the 1986 / 87 budget delivered last August . Australia \' s terms of trade also fell , by 18 pct , over the past two years , he told Parliament . Terms of trade are the difference between import and export price indexes . Despite the figures , the budget forecast of about 1 . 75 pct annual growth in employment would be met , Keating said . Unemployment is currently at 8 . 2 pct of the workforce . " This government is dragging Australia through a trading holocaust the kind of which we have not seen since the Second World War ," Keating said . " We are not pushing this place into a recession . We are not only holding our gains on unemployment , we are bringing unemployment down ," he said , adding that the government had help the country avoid recession .'

# %%
resultult = result.replace(" . ", ".")
result = result.replace("pct","%")
result
# Out:
# 'KEATING REVISES DOWN AUSTRALIAN GROWTH FORECAST Treasurer Paul Keating forecast economic growth at slightly under two % in the financial year ending June this year , down from the 2 . 25 % forecast contained in the 1986 / 87 budget delivered last August . Australia \' s terms of trade also fell , by 18 % , over the past two years , he told Parliament . Terms of trade are the difference between import and export price indexes . Despite the figures , the budget forecast of about 1 . 75 % annual growth in employment would be met , Keating said . Unemployment is currently at 8 . 2 % of the workforce . " This government is dragging Australia through a trading holocaust the kind of which we have not seen since the Second World War ," Keating said . " We are not pushing this place into a recession . We are not only holding our gains on unemployment , we are bringing unemployment down ," he said , adding that the government had help the country avoid recession .'

# %%
import spacy
from spacy import displacy
import en_core_web_sm

# Create an instance of the small pipeline and model from SpaCy
nlp = en_core_web_sm.load()

# Apply the complete NER pipeline from SpaCy (preprocessing + model prediction)
doc = nlp(result)

# Show the entities detected in a nice way
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">KEATING REVISES DOWN AUSTRALIAN GROWTH FORECAST Treasurer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Keating
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  forecast economic growth at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     slightly under two %
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %% [markdown]
# ## NER using Spacy

# %% [markdown]
# ### Extracting the entities and labels

# %%
import pandas as pd
import nltk

doc = nlp(result)

entities = []
labels = []

for ent in doc.ents:
    entities.append(ent)
    labels.append(ent.label_)
    
df = pd.DataFrame({'Entities':entities,'Labels':labels})

df
# Out:
#                                             Entities    Labels
# 0                                    (Paul, Keating)    PERSON
# 1                          (slightly, under, two, %)   PERCENT
# 2   (the, financial, year, ending, June, this, year)      DATE
# 3                                            (25, %)   PERCENT
# 4                                             (1986)      DATE
# 5                                     (last, August)      DATE
# 6                                        (Australia)       GPE
# 7                                            (18, %)   PERCENT
# 8                            (the, past, two, years)      DATE
# 9                                       (Parliament)       ORG
# 10                                        (about, 1)  CARDINAL
# 11                                           (75, %)   PERCENT
# 12                                          (annual)      DATE
# 13                                         (Keating)    PERSON
# ...

# %%
top_entities = (df.groupby(by=['Entities', 'Labels'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))

# %%
named_entities = []
for sentence in result:
    temp_entity_name = ''
    temp_named_entity = None
    sentence = nlp(result)
    for word in sentence:
        term = word.text 
        tag = word.ent_type_
        if tag:
            temp_entity_name = ' '.join([temp_entity_name, term]).strip()
            temp_named_entity = (temp_entity_name, tag)
        else:
            if temp_named_entity:
                named_entities.append(temp_named_entity)
                temp_entity_name = ''
                temp_named_entity = None

entity_frame = pd.DataFrame(named_entities, 
                            columns=['Entity Name', 'Entity Type'])

# %%
# get the top named entities
top_entities = (entity_frame.groupby(by=['Entity Name', 'Entity Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.T.iloc[:,:17]
# Out:
#                     0        1        2     3        4            5        6   \
# Entity Name  Australia  Keating     18 %  1986     25 %  75 % annual  8 . 2 %
# Entity Type        GPE   PERSON  PERCENT  DATE  PERCENT         DATE  PERCENT
# Frequency         1934     1934      967   967      967          967      967
#
#                      7             8         9            10  \
# Entity Name  Parliament  Paul Keating   about 1  last August
# Entity Type         ORG        PERSON  CARDINAL         DATE
# Frequency           967           967       967          967
#
#                                11                    12  \
# Entity Name  slightly under two %  the Second World War
# Entity Type               PERCENT                 EVENT
# Frequency                     967                   967
#
#                                                    13                  14
# Entity Name  the financial year ending June this year  the past two years
# ...

# %%
# Extract only the entities fromt the document 
doc = nlp(result)
print(*[(e.text, e.label_) for e in doc.ents], sep=' ')
# Out:
# ('Paul Keating', 'PERSON') ('slightly under two %', 'PERCENT') ('the financial year ending June this year', 'DATE') ('25 %', 'PERCENT') ('1986', 'DATE') ('last August', 'DATE') ('Australia', 'GPE') ('18 %', 'PERCENT') ('the past two years', 'DATE') ('Parliament', 'ORG') ('about 1', 'CARDINAL') ('75 %', 'PERCENT') ('annual', 'DATE') ('Keating', 'PERSON') ('8 .', 'PERCENT') ('2 %', 'PERCENT') ('Australia', 'GPE') ('the Second World War', 'EVENT') ('Keating', 'PERSON')

# %% [markdown]
# ### Part-of-Speech POS tags for words in document

# %%
words = nltk.word_tokenize(result)
#Part of speech tagging
pos_tags = nltk.pos_tag(words)
#pos_tags

# %% [markdown]
# ### Extract the sentences from the document into .csv file

# %%
from spacy.lang.en import English

#sent1 = "Half of all people living in Belgium has now received a coronavirus booster dose, as new cases continue to rapidly increase as a result of the Omicron variant. As of Sunday, some 5.87 million people have received a booster dose of a coronavirus vaccine, representing 63% of over -18s and 51% of the entire population, according to the figures published by the Sciensano Public Health Institute on Tuesday morning."

nlp = English()
nlp.add_pipe('sentencizer')
doc = nlp(result)
sent= [sent.text.strip() for sent in doc.sents]
sent
# Out:
# ['KEATING REVISES DOWN AUSTRALIAN GROWTH FORECAST Treasurer Paul Keating forecast economic growth at slightly under two % in the financial year ending June this year , down from the 2 .',
#  '25 % forecast contained in the 1986 / 87 budget delivered last August .',
#  "Australia ' s terms of trade also fell , by 18 % , over the past two years , he told Parliament .",
#  'Terms of trade are the difference between import and export price indexes .',
#  'Despite the figures , the budget forecast of about 1 .',
#  '75 % annual growth in employment would be met , Keating said .',
#  'Unemployment is currently at 8 .',
#  '2 % of the workforce . "',
#  'This government is dragging Australia through a trading holocaust the kind of which we have not seen since the Second World War ," Keating said . "',
#  'We are not pushing this place into a recession .',
# ...

# %%
df1= pd.DataFrame(columns=["sentence"])

df1 = df1.append(
        [{'sentence' : sent.text} for sent in nlp(result).sents],
        ignore_index=True
    )
df1
# Out:
#                                              sentence
# 0   KEATING REVISES DOWN AUSTRALIAN GROWTH FORECAS...
# 1   25 % forecast contained in the 1986 / 87 budge...
# 2   Australia ' s terms of trade also fell , by 18...
# 3   Terms of trade are the difference between impo...
# 4   Despite the figures , the budget forecast of a...
# 5   75 % annual growth in employment would be met ...
# 6                    Unemployment is currently at 8 .
# 7                            2 % of the workforce . "
# 8   This government is dragging Australia through ...
# 9    We are not pushing this place into a recession .
# 10  We are not only holding our gains on unemploym...

# %%
df1.to_csv("data.csv")  # Save the dataset as a csv for our knowledge graph implementation.

# %% [markdown]
# ## Visualization of the document

# %%
displacy.render(doc, style="dep",options={'compact': True, 'distance': 200})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="95acecaacc6f4c6293d5fb15d5bc7e13-0" class="displacy" width="31050" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">KEATING</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">REVISES</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

# %%
plt.figure(figsize = (20,20)) 
wc = WordCloud(max_words = 1000 , width = 1600 , height = 800).generate(result)
plt.imshow(wc , interpolation = 'bilinear')

# %% [markdown]
# ## Entity Linking
# source: https://towardsdatascience.com/from-text-to-knowledge-the-information-extraction-pipeline-b65e7e30273e

# %%
import urllib
from string import punctuation
import nltk

ENTITY_TYPES = ["human", "person", "company", "enterprise", "business", "geographic region",
                "country", "human settlement", "geographic entity", "territorial entity type", "organization"]

def wikifier(text, lang="en", threshold=0.8):
    """Function that fetches entity linking results from wikifier.com API"""
    # Prepare the URL.
    data = urllib.parse.urlencode([
        ("text", text), ("lang", lang),
        ("userKey", "tgbdmkpmkluegqfbawcwjywieevmza"),
        ("pageRankSqThreshold", "%g" %
         threshold), ("applyPageRankSqThreshold", "true"),
        ("nTopDfValuesToIgnore", "100"), ("nWordsToIgnoreFromList", "100"),
        ("wikiDataClasses", "true"), ("wikiDataClassIds", "false"),
        ("support", "true"), ("ranges", "false"), ("minLinkFrequency", "2"),
        ("includeCosines", "false"), ("maxMentionEntropy", "3")
    ])
    url = "http://www.wikifier.org/annotate-article"
    # Call the Wikifier and read the response.
    req = urllib.request.Request(url, data=data.encode("utf8"), method="POST")
    with urllib.request.urlopen(req, timeout=60) as f:
        response = f.read()
        response = json.loads(response.decode("utf8"))
    # Output the annotations.
    results = list()
    for annotation in response["annotations"]:
        # Filter out desired entity classes
        if ('wikiDataClasses' in annotation) and (any([el['enLabel'] in ENTITY_TYPES for el in annotation['wikiDataClasses']])):

            # Specify entity label
            if any([el['enLabel'] in ["human", "person"] for el in annotation['wikiDataClasses']]):
                label = 'Person'
            elif any([el['enLabel'] in ["country", "geographic region", "human settlement", "geographic entity", "territorial entity type"] for el in annotation['wikiDataClasses']]):
                label = 'Location'
            elif any([el['enLabel'] in ["company", "enterprise", "business", "organization"] for el in annotation['wikiDataClasses']]):
                label = 'Organization'
    
            else:
                label = None

            results.append({'title': annotation['title'], 'wikiId': annotation['wikiDataItemId'], 'label': label,
                            'characters': [(el['chFrom'], el['chTo']) for el in annotation['support']]})
    return results

# %%
import json
linking = wikifier(result)
linking
# Out:
# [{'title': 'Paul Keating',
#   'wikiId': 'Q242654',
#   'label': 'Person',
#   'characters': [(58, 69), (63, 69), (533, 539), (737, 743)]},
#  {'title': 'Australia',
#   'wikiId': 'Q408',
#   'label': 'Location',
#   'characters': [(256, 264), (634, 642)]}]

# %%
output = pd.DataFrame()
df = output.append(linking, ignore_index=True)
df
# Out:
#           title   wikiId     label  \
# 0  Paul Keating  Q242654    Person
# 1     Australia     Q408  Location
#
#                                      characters
# 0  [(58, 69), (63, 69), (533, 539), (737, 743)]
# 1                      [(256, 264), (634, 642)]
