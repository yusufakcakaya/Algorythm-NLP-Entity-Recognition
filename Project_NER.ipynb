# %% [markdown]
# ### Loading the dataset

# %%
from nltk.corpus import reuters

# %%
import nltk
nltk.download('reuters')
# Out:
# [nltk_data] Downloading package reuters to C:\Users\Nichelle
# [nltk_data]     Machado\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# True

# %%
reuters.fileids()[:10]
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843']

# %%
cats = reuters.categories()
print("Reuters has %d categories:\n%s" % (len(cats), cats))
# Out:
# Reuters has 90 categories:
# ['acq', 'alum', 'barley', 'bop', 'carcass', 'castor-oil', 'cocoa', 'coconut', 'coconut-oil', 'coffee', 'copper', 'copra-cake', 'corn', 'cotton', 'cotton-oil', 'cpi', 'cpu', 'crude', 'dfl', 'dlr', 'dmk', 'earn', 'fuel', 'gas', 'gnp', 'gold', 'grain', 'groundnut', 'groundnut-oil', 'heat', 'hog', 'housing', 'income', 'instal-debt', 'interest', 'ipi', 'iron-steel', 'jet', 'jobs', 'l-cattle', 'lead', 'lei', 'lin-oil', 'livestock', 'lumber', 'meal-feed', 'money-fx', 'money-supply', 'naphtha', 'nat-gas', 'nickel', 'nkr', 'nzdlr', 'oat', 'oilseed', 'orange', 'palladium', 'palm-oil', 'palmkernel', 'pet-chem', 'platinum', 'potato', 'propane', 'rand', 'rape-oil', 'rapeseed', 'reserves', 'retail', 'rice', 'rubber', 'rye', 'ship', 'silver', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'strategic-metal', 'sugar', 'sun-meal', 'sun-oil', 'sunseed', 'tea', 'tin', 'trade', 'veg-oil', 'wheat', 'wpi', 'yen', 'zinc']

# %%
# total = len(reuters.paras())
# total_multi = 0
# for c in cats:
#     lc = len(reuters.paras(categories=[c]))
#     total_multi += lc
#     print("%s ---- %d documents out of %d" % (c, lc, total))
# print("Articles belong to %.4f categories on average" % ((total_multi * 1.0) / total))
# print("There are %.4f articles per category on average" % ((total * 1.0) / len(cats)))

# %%
reuters.fileids(categories=['cpi'])
# Out:
# ['test/14891',
#  'test/14918',
#  'test/16103',
#  'test/16108',
#  'test/16118',
#  'test/16134',
#  'test/16158',
#  'test/16226',
#  'test/16241',
#  'test/16268',
#  'test/16415',
#  'test/16740',
#  'test/16783',
#  'test/17442',
#  'test/17970',
#  'test/18001',
#  'test/18987',
#  'test/18993',
#  'test/19000',
#  'test/19005',
#  'test/19079',
#  'test/19081',
#  'test/19513',
#  'test/19625',
#  'test/19653',
#  'test/20247',
#  'test/21130',
#  'test/21532',
#  'training/10260',
#  'training/10261',
#  'training/10377',
#  'training/10384',
#  'training/10385',
#  'training/10553',
#  'training/10567',
#  'training/10724',
#  'training/11197',
#  'training/1147',
#  'training/11894',
#  'training/12080',
#  'training/12464',
#  'training/12771',
#  'training/13007',
#  'training/13172',
#  'training/13333',
#  'training/14770',
#  'training/1550',
#  'training/1681',
#  'training/179',
#  'training/209',
#  'training/213',
#  'training/2529',
#  'training/2555',
#  'training/3024',
#  'training/3411',
#  'training/3593',
#  'training/4486',
#  'training/4548',
#  'training/4555',
#  'training/4573',
#  'training/4741',
#  'training/5145',
#  'training/5194',
#  'training/5231',
#  'training/5238',
#  'training/5245',
#  'training/5260',
#  'training/5318',
#  'training/5375',
#  'training/5378',
#  'training/5389',
#  'training/5490',
#  'training/5523',
#  'training/5830',
#  'training/6385',
#  'training/6406',
#  'training/6920',
#  'training/6965',
#  'training/6982',
#  'training/7177',
#  'training/7314',
#  'training/7580',
#  'training/7584',
#  'training/7590',
#  'training/7591',
#  'training/8119',
#  'training/8164',
#  'training/8211',
#  'training/8694',
#  'training/8726',
#  'training/8746',
#  'training/9165',
#  'training/929',
#  'training/9294',
#  'training/9433',
#  'training/9824',
#  'training/9829']

# %% [markdown]
# ### Choosing the document and converting it to a string

# %%
s = reuters.words('training/1147')

# %%
def listToString(s): 
    
    # initialize an empty string
    str1 = " " 
    
    # return string  
    return (str1.join(s))

# %%
string= listToString(s)
string
# Out:
# "CHILEAN CONSUMER PRICES RISE 1 . 7 PCT IN FEBRUARY Chile ' s consumer price index rose 1 . 7 pct in February to 562 . 01 ( December , 1978 equals 100 ) after increases of 2 . 0 pct in January and 0 . 9 pct in February 1986 , the government ' s National Statistics Institute said . Inflation as measured by the index rose to 17 . 5 pct over the 12 months to the end of February , compared with 16 . 6 pct last month and 24 . 5 pct to the end of February , 1986 . In the first two months of the year , inflation was 3 . 8 pct , against 3 . 6 pct in the same period of 1986 ."

# %% [markdown]
# ### Preprocessing

# %%
import re

# Code to remove special characters
string = string.replace("'", "") #apostrophe
string = string.replace('"',"") #double quotes
#string = string.replace(",","") #comma
string = string.replace(" . ", ".") #removing space between '.'
#string = string.replace(" / ", "/") #removing space between '/'
string = re.sub('\s+[a-zA-Z]\s+', ' ',string) #removing single alphabetical characters
string = re.sub(" pct|PCT", "%", string) #replacing 'pct' with the symbol '%'
string = string.replace("dlrs","dlr")
string = string.replace("mln", "million")
string = string.replace("U.S.", "United States of America ")

# %%
string
# Out:
# 'CHILEAN CONSUMER PRICES RISE 1.7 % IN FEBRUARY Chile consumer price index rose 1.7% in February to 562.01 ( December , 1978 equals 100 ) after increases of 2.0% in January and 0.9% in February 1986 , the government National Statistics Institute said.Inflation as measured by the index rose to 17.5% over the 12 months to the end of February , compared with 16.6% last month and 24.5% to the end of February , 1986.In the first two months of the year , inflation was 3.8% , against 3.6% in the same period of 1986 .'

# %%
# import nltk
# from nltk.corpus import stopwords
# nltk.download('stopwords')

# %%
# stop_words = stopwords.words('english')

# def remove_stopwords(text):
#     text = ' '.join(word for word in text.split(' ') if word not in stop_words)
#     return text
    
# string = remove_stopwords(string)

# %% [markdown]
# ### Entity Linking

# %% [markdown]
# source: https://towardsdatascience.com/from-text-to-knowledge-the-information-extraction-pipeline-b65e7e30273e

# %%
import urllib
from string import punctuation
import nltk

ENTITY_TYPES = ["human", "person", "company", "enterprise", "business", "geographic region",
                "human settlement", "geographic entity", "territorial entity type", "organization"]

def wikifier(text, lang="en", threshold=0.8):
    """Function that fetches entity linking results from wikifier.com API"""
    # Prepare the URL.
    data = urllib.parse.urlencode([
        ("text", text), ("lang", lang),
        ("userKey", "tgbdmkpmkluegqfbawcwjywieevmza"),
        ("pageRankSqThreshold", "%g" %
         threshold), ("applyPageRankSqThreshold", "true"),
        ("nTopDfValuesToIgnore", "100"), ("nWordsToIgnoreFromList", "100"),
        ("wikiDataClasses", "true"), ("wikiDataClassIds", "false"),
        ("support", "true"), ("ranges", "false"), ("minLinkFrequency", "2"),
        ("includeCosines", "false"), ("maxMentionEntropy", "3")
    ])
    url = "http://www.wikifier.org/annotate-article"
    # Call the Wikifier and read the response.
    req = urllib.request.Request(url, data=data.encode("utf8"), method="POST")
    with urllib.request.urlopen(req, timeout=60) as f:
        response = f.read()
        response = json.loads(response.decode("utf8"))
    # Output the annotations.
    results = list()
    for annotation in response["annotations"]:
        # Filter out desired entity classes
        if ('wikiDataClasses' in annotation) and (any([el['enLabel'] in ENTITY_TYPES for el in annotation['wikiDataClasses']])):

            # Specify entity label
            if any([el['enLabel'] in ["human", "person"] for el in annotation['wikiDataClasses']]):
                label = 'Person'
            elif any([el['enLabel'] in ["company", "enterprise", "business", "organization"] for el in annotation['wikiDataClasses']]):
                label = 'Organization'
            elif any([el['enLabel'] in ["geographic region", "human settlement", "geographic entity", "territorial entity type"] for el in annotation['wikiDataClasses']]):
                label = 'Location'
            else:
                label = None

            results.append({'title': annotation['title'], 'wikiId': annotation['wikiDataItemId'], 'label': label,
                            'characters': [(el['chFrom'], el['chTo']) for el in annotation['support']]})
    return results

# %%
import json

# %%
linking = wikifier(string)

# %%
linking
# Out:
# [{'title': 'Chile',
#   'wikiId': 'Q298',
#   'label': 'Organization',
#   'characters': [(0, 6), (47, 51)]},
#  {'title': 'National Statistics Institute (Chile)',
#   'wikiId': 'Q3288549',
#   'label': 'Organization',
#   'characters': [(215, 243)]}]

# %%
import pandas as pd

# %%
output = pd.DataFrame()
df = output.append(linking, ignore_index=True)
df
# Out:
#                                    title    wikiId         label  \
# 0                                  Chile      Q298  Organization
# 1  National Statistics Institute (Chile)  Q3288549  Organization
#
#            characters
# 0  [(0, 6), (47, 51)]
# 1        [(215, 243)]

# %% [markdown]
# ### Relation Extraction

# %%
# import itertools

# %%
# import opennre

# %%
# # First get all the entities in the sentence
# entities = wikifier(string, threshold=0.8)
# # Iterate over every permutation pair of entities
# for permutation in itertools.permutations(entities, 2):
#     for source in permutation[0]['characters']:
#         for target in permutation[1]['characters']:
#             # Relationship extraction with OpenNRE
#             data = relation_model.infer(
#                 {'text': sentence, 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
#             if data[1] > relation_threshold:
#                 relations_list.append(
#                     {'source': permutation[0]['title'], 'target': permutation[1]['title'], 'type': data[0]})

# %% [markdown]
# ### NER

# %%
# Load the needed dependencies from SpaCy
import spacy
from spacy import displacy
import en_core_web_trf

# Create an instance of the small pipeline and model from SpaCy
nlp = en_core_web_trf.load()

# %%
# Apply the complete NER pipeline from SpaCy (preprocessing + model prediction)
doc = nlp(string)

# Show the entities detected in a nice way
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHILEAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  CONSUMER PRICES RISE
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.7 %
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  IN
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FEBRUARY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  consumer price index rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     562.01
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December , 1978
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  equals
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ) after increases of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.0%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.9%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , the government
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     National Statistics Institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said.Inflation as measured by the index rose to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 12 months to the end of February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , compared with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of February , 1986.In
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first two months of the year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , inflation was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.8%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  , against
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the same period of 1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  .</div></span>

# %%
# Loop over all the tokens preprocessed by SpaCy
for token in doc:
    # If the token is detected as an entity
    if token.ent_type_:
        print(f"{token.text}: {token.ent_type_}")
# Out:
# CHILEAN: NORP
# 1.7: PERCENT
# %: PERCENT
# FEBRUARY: DATE
# Chile: GPE
# 1.7: PERCENT
# %: PERCENT
# February: DATE
# 562.01: CARDINAL
# December: DATE
# ,: DATE
# 1978: DATE
# 100: CARDINAL
# 2.0: PERCENT
# %: PERCENT
# January: DATE
# 0.9: PERCENT
# %: PERCENT
# February: DATE
# 1986: DATE
# National: ORG
# Statistics: ORG
# Institute: ORG
# 17.5: PERCENT
# %: PERCENT
# the: DATE
# 12: DATE
# months: DATE
# to: DATE
# the: DATE
# end: DATE
# of: DATE
# February: DATE
# 16.6: PERCENT
# %: PERCENT
# last: DATE
# month: DATE
# 24.5: PERCENT
# %: PERCENT
# the: DATE
# end: DATE
# of: DATE
# February: DATE
# ,: DATE
# 1986.In: DATE
# the: DATE
# first: DATE
# two: DATE
# months: DATE
# of: DATE
# the: DATE
# year: DATE
# 3.8: PERCENT
# %: PERCENT
# 3.6: PERCENT
# %: PERCENT
# the: DATE
# same: DATE
# period: DATE
# of: DATE
# 1986: DATE

# %%
entity_type=[]
entity=[]
for token in doc:
    if token.ent_type_:
        entity.append(token.text)
        entity_type.append(token.ent_type_)

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(zip(entity, entity_type)), columns=['Entity', 'Entity Type'])

# %%
df
# Out:
#       Entity Entity Type
# 0    CHILEAN        NORP
# 1        1.7     PERCENT
# 2          %     PERCENT
# 3   FEBRUARY        DATE
# 4      Chile         GPE
# ..       ...         ...
# 56       the        DATE
# 57      same        DATE
# 58    period        DATE
# 59        of        DATE
# 60      1986        DATE
#
# [61 rows x 2 columns]

# %% [markdown]
# ### Visualization of the document

# %%
displacy.render(doc, style="dep",options={'compact': True, 'distance': 200})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e6d0915762874660b93876872e0601aa-0" class="displacy" width="17450" height="1237.0" direction="ltr" style="max-width: none; height: 1237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">CHILEAN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">CONSUMER</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">PRICES</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">RISE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">1.7 %</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">IN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">FEBRUARY</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Chile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">consumer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">index</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">rose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">1.7%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">February</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="3250">562.01 (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="3450">December ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">1978</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="3850">equals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="4050">100 )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="4450">increases</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="4650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="4850">2.0%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="5050">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="5250">January</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="5450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="5650">0.9%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="5850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1147.0">
#     <tspan class="displacy-word" fill="currentColor" x="6050">February</tspan>
#     <ts

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

# %%
plt.figure(figsize = (20,20)) 
wc = WordCloud(max_words = 1000 , width = 1600 , height = 800).generate(string)
plt.imshow(wc , interpolation = 'bilinear')

# %% [markdown]
# ### Entity Relation Extraction

# %%
# import re 
# import string 
# import nltk 
# import spacy 
# import pandas as pd 
# import numpy as np 
# import math 
# from tqdm import tqdm 

# from spacy.matcher import Matcher 
# from spacy.tokens import Span 
# from spacy import displacy 

# pd.set_option('display.max_colwidth', 200)

# %%
# # print token, dependency, POS tag 
# for tok in doc: 
#   print(tok.text, "-->",tok.dep_,"-->", tok.pos_)

# %%
# #define the pattern 
# pattern = [{'POS':'NOUN'}, 
#            {'LOWER': 'index'}, 
#            {'LOWER': 'to'}, 
#            {'POS': 'PROPN'}]
